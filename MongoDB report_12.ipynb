# %% [markdown]
# ---
#
# ### **Project Report: MongoDB Dashboard**
# **Analysis of Movies Collection in MongoDB**
# **Group 25**
# Himanshi Sharma (055012)
# Ankit Sharma (055059)
# ---
#
# ### 1. Project Overview
#
# This project focuses on conducting an analysis of a Movies dataset using MongoDB.
# The dataset, formatted in JSON, is ideally suited for MongoDB’s document-based structure.
# The team utilized **MongoDB Compass** for executing queries and performing CRUD operations, and **MongoDB Atlas** was employed to build visualizations for insightful analysis.
#
# ---
#
# ### 2. Data Overview
#
# The **movies** collection, sourced from the Mflix dataset, holds **23,149 documents**, occupying approximately **1.2 GB** of storage within MongoDB Atlas.
# Each document represents a movie and contains attributes such as title, genre, cast, and ratings.
# Being semi-structured (BSON format), the data contains nested fields and arrays, allowing for complex and flexible queries.
#
# Each document generally includes:
#
# - **_id (ObjectId):**
#   Unique identifier for each movie.
#   Example: `"5a934e000102030405000000"`
#
# - **title (String):**
#   Movie name.
#   Example: `"Inception"`
#
# - **year (Number):**
#   Year the movie was released.
#   Example: `2010`
#
# - **genres (Array of Strings):**
#   Categories the movie belongs to.
#   Example: `["Action", "Sci-Fi", "Thriller"]`
#
# - **cast (Array of Strings):**
#   List of actors featured.
#   Example: `["Leonardo DiCaprio", "Joseph Gordon-Levitt", "Elliot Page"]`
#
# - **directors (Array of Strings):**
#   Directors' names.
#   Example: `["Christopher Nolan"]`
#
# - **writers (Array of Strings):**
#   Writers or screenwriters.
#   Example: `["Christopher Nolan", "Jonathan Nolan"]`
#
# - **languages (Array of Strings):**
#   Languages the movie is available in.
#   Example: `["English", "Japanese", "French"]`
#
# - **countries (Array of Strings):**
#   Countries where the movie was produced.
#   Example: `["USA", "UK"]`
#
# - **released (Date):**
#   Official release date.
#   Example: `ISODate("2010-07-16T00:00:00Z")`
#
# - **runtime (Number):**
#   Movie duration in minutes.
#   Example: `148`
#
# - **plot (String):**
#   A brief storyline summary.
#   Example:
#   `"A thief who steals corporate secrets through dream-sharing technology is given a chance to erase his criminal record."`
#
# - **fullplot (String):**
#   A detailed plot summary.
#
# - **imdb (Object):**
#   IMDb specific details:
#   - **rating (Number):** IMDb rating (e.g., 8.8)
#   - **votes (Number):** Number of votes received (e.g., 2,000,000)
#   - **id (Number):** IMDb movie ID (e.g., 1375666)
#
# - **tomatoes (Object):**
#   Rotten Tomatoes related data:
#   - **viewer (Object):** Viewer rating and reviews.
#   - **rating (Number):** Viewer rating (e.g., 4.2)
#   - **numReviews (Number):** Viewer reviews count (e.g., 5000)
#   - **critic (Object):** Critic reviews.
#   - **fresh (Number):** Fresh ratings count.
#   - **rotten (Number):** Rotten ratings count.
#   - **lastUpdated (Date):** Last update timestamp.
#
# - **type (String):**
#   Type of media (generally `"movie"`).
#
#
# ---
#
# ### 3. Project Objectives
#
# - To design a **structured dashboard** that highlights major insights from the Movies collection of the Mflix dataset.
# - To **explore relationships** between movie features like genre, ratings, and release year through **visualizations**.
# - To efficiently perform **CRUD operations** (Create, Read, Update, Delete) on the dataset using MongoDB queries.
# - To **generate insightful reports** that support **data-driven decision-making** and **trend analysis** in the film industry.
#
# ---
#
# ### 4. Queries (Using MongoDB Compass)
#
# **Create Operations:**
# - **Insert a New Movie:**
#   Add a new movie document to the collection.
#   ![image.png](data:image/png;base64,...)
#
# - **Insert Multiple Temporary Movies:**
#   Bulk insertion of temporary movie documents for testing or analysis.
#   ![image.png](data:image/png;base64,...)
#
# **Retrieve Operations:**
# - **Find All Temporary Movies:**
#   Query to retrieve all documents categorized as temporary movies.
#   ![image.png](data:image/png;base64,...)
#
# - **Find Movies with an IMDb Rating Above 8.5:**
#   Retrieve movies that have received exceptionally high IMDb ratings.
#   ![image.png](data:image/png;base64,...)
#
# - **Count Movies in the "Action" Genre:**
#   Calculate how many movies belong to the Action genre.
#   ![image.png](data:image/png;base64,...)
#
# **Update Operations:**
# - **Update IMDb Rating of a Temporary Movie:**
#   Modify the IMDb rating field for a specific temporary movie.
#   ![image.png](data:image/png;base64,...)
#
# - **Add a New Genre to a Temporary Movie:**
#   Update the genre array of a movie by adding a new category.
#   ![image.png](data:image/png;base64,...)
#
# - **Update the Year for Multiple Temporary Movies:**
#   Batch update the release year for selected temporary movies.
#   ![image.png](data:image/png;base64,...)
#
# **Delete Operations:**
# - **Delete a Specific Temporary Movie:**
#   Remove a selected temporary movie from the database.
#   ![image.png](data:image/png;base64,...)
#
# - **Delete All Temporary Movies:**
#   Bulk delete all documents marked as temporary movies.
#   ![image.png](data:image/png;base64,...)
#
# ---
#
# ### 5. Problem Statement
#
# The film industry faces difficulties in analyzing **large volumes of unstructured data** to **predict emerging trends** and **optimize content**.
# Conventional methods often fail to provide actionable insights about **genre popularity**, **audience ratings**, and **production patterns**, making it harder for industry stakeholders to make **data-driven decisions**.
#
# ---
#
# ### 6. Dashboard Overview
#
# The team created a **MongoDB Atlas Dashboard** to visualize **key metrics** from the Movies dataset.
# The following visualizations and problem statements were addressed:
#
# ---
#
# **II. Top 10 Movies by IMDb Rating**
# **Problem Statement:**
# Sum of Runtime by Cast
# This bar graph displays the total runtime (in minutes) for movies associated with each actor.
# The top actors with the highest cumulative screen time are presented.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **III.Language Distribution of Movies**
# **Problem Statement**
# This donut chart displays the proportion of movies by language.
# ![image.png](data:image/png;base64,...)
# ---
#
# **IV.Titleles by Number of Countries Produced**
# **Problem Statement**
# This bar chart shows the number of countries involved in producing specific movie titles.
# The movies listed are those that had multi-country collaborations.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **V. Genre-wise Average Rating**
# **Problem Statement:**
# Calculate the average IMDb rating for each genre to determine which genres consistently perform better.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **VI. Most Common Languages**
# **Problem Statement:**
# Identify the most prevalent languages among movies to assess the linguistic diversity within the dataset.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **VII. Comparison of IMDb and Rotten Tomatoes Ratings**
# **Problem Statement:**
# Compare IMDb ratings with Rotten Tomatoes ratings to find patterns or differences between audience and critic perspectives.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **VIII. Genre by movie count**
# **Problem Statement:**
#
# This area chart displays the number of movies produced in each genre based on the count of full plots available in the dataset.
# ![image.png](data:image/png;base64,...)
# ---
#
# **IX. Average Awards Won in Each Genre**
# **Problem Statement:**
# Evaluate which genres tend to win the most awards on average.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **X. Directors from diff countries**
# This line chart shows the number of directors originating from different countries based on the movie dataset.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **XI. Total Movies (Number Card)**
# **Problem Statement:**
# Present the total number of movies available in the dataset as a key summary statistic.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **XII. Average IMDb Rating for Action Genre**
# **Problem Statement:**
# Calculate the average IMDb rating specifically for Action movies to evaluate their performance.
# ![image.png](data:image/png;base64,...)
# ---
#
# **XIII. Mvie Plot Updates Over Time**
# **Problem Statement:**
#
# This bar graph (colored intensity chart) shows the count of movie plots updated on specific dates, based on the lastupdated timestamp field.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **XIV. Ratings Across Decades and Genres**
# **Problem Statement:**
# Investigate how movie ratings have shifted across decades, broken down by genre.
# ![image.png](data:image/png;base64,...)
#
# ---
#
# **XV. Directors with Highest Number of Movies**
# **Problem Statement:**
# Identify directors with the most movies produced and explore their favored genres.
# ![image.png](data:image/png;base64,...)
# ---
#
# **XVI. Movie Ratings by Genre**
# **Problem Statement:**
# Summarize the overall movie ratings based on genre to offer a quick quality assessment.
# ![image.png](data:image/png;base64,...)
#
# ---
#
#
#
# ---
#
#
# ### 7. Observations and Findings
#
# **1. Movie Distribution by Genre**
# - Genres like **Drama**, **Action**, and **Comedy** dominate movie production, making them the most widely created genres.
# - **Sci-Fi** and **Thriller** films often secure higher ratings, indicating a smaller but highly engaged fan base.
#
# **2. IMDb Ratings Analysis**
# - The majority of films have IMDb ratings between **6.0 and 8.0**, with very few exceeding **8.5**.
# - High-rated movies are predominantly in the **Drama** and **Thriller** categories, showing a preference for well-constructed narratives.
# - Movies rated above **8.0** usually maintain longer audience engagement times.
#
# **3. Trends in Yearly Movie Production**
# - Movie production surged significantly after **2000**, highlighting the influence of **digital media and streaming services**.
# - During the **1980s and 1990s**, movie output remained steady, but a sharp growth trajectory started in the new millennium.
#
# **4. Language Distribution**
# - **English** remains the leading language in the dataset, followed by noticeable contributions from **Spanish**, **French**, and **Hindi**.
# - A growing trend of **multilingual films** reflects the film industry's increasing globalization.
#
# **5. Runtime Analysis**
# - Most movies have runtimes between **90 to 150 minutes**, with only a few exceeding the **3-hour mark**.
# - **Short films** and **documentaries** generally have much shorter durations.
#
# **6. Awards and Ratings Correlation**
# - Films with higher IMDb ratings are more likely to be **nominated for or win awards**.
# - There’s a strong link between **higher Rotten Tomatoes critic scores** and **award wins**.
#
# ---
#
# ### 5. Impact of Streaming Services & Future Outlook
#
# - The sharp rise in movie releases after 2000 can be attributed to **streaming platforms** and **digital production technologies**.
# - Emerging genres like **Documentaries** and **Biographical films** are projected to experience significant growth in the near future.
#
# ---
#
# ### 6. Director Analysis
#
# - Directors with the highest film counts usually specialize in **specific genres**, demonstrating a clear creative focus.
# - Directors who consistently earn high **Metacritic scores** tend to achieve critical success, regardless of the genre.
#
# ---
#
# ### 7. Critic and Viewer Ratings Comparison
#
# - A notable **gap often exists** between **critic (Metacritic)** and **audience (IMDb)** ratings, suggesting differing perspectives on movie quality.
# - **Drama** and **Thriller** genres usually receive better critic scores, whereas **Action** and **Comedy** genres often have mixed reviews.
# - Some niche genres like **Film Noir** showcase extremely high Metacritic ratings, but due to a **limited number of films**, these averages can appear inflated.
#
# ---
#
# ### 8. Award Analysis
#
# - The **percentage of award wins** varies significantly across genres — **Drama** and **Thriller** movies typically have higher win rates compared to **Comedy** or **Action**.
# - A strong IMDb rating doesn’t always guarantee award wins, implying that **critical acclaim** and **formal recognition** do not always align.
#
# ---
#
# ### 9. Language and Regional Preferences
#
# - While **English** remains dominant, **Spanish**, **French**, and **Hindi** films demonstrate the growing global footprint of cinema.
# - The increasing success of **multilingual productions** points towards a rising demand for **culturally diverse storytelling**.
#
# ---
#
# ### 8. Managerial Recommendations
#
# **1. Strategic Content Planning**
# - Prioritize producing **Drama**, **Thriller**, and **Sci-Fi** films, as they tend to attract dedicated audiences and higher critical scores.
# - Balance investment between **high-budget Action blockbusters** and **quality-driven Dramas** to maximize both revenue and reputation.
#
# **2. Targeted Marketing Campaigns**
# - Emphasize promoting **award-winning** and **critically acclaimed** films to niche audiences.
# - Utilize **star power** and **visual effects** when marketing movies with moderate ratings but high entertainment value.
#
# **3. Platform and Regional Strategy**
# - Develop more **multilingual content** to cater to global audiences and broaden the market reach.
# - Tailor distribution strategies to match **regional preferences** on streaming platforms.
#
# **4. Future Genre Focus**
# - Encourage production of **Documentaries** and **Biographical films**, which are emerging as popular categories in the digital era.
# - Use insights about the **critic-audience rating gap** to better position and promote films that appeal to broader audiences.
#
# ---
